# %%
import pandas as pd

# %%
station_day = pd.read_csv(r'Datasets/air_quality/station_day.csv')

# %%
station_day.head(10)
# Out:
#   StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0     AP001  2017-11-24  71.36  115.75  1.75  20.65  12.40  12.19  0.10
# 1     AP001  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2     AP001  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3     AP001  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4     AP001  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09
# 5     AP001  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25  0.16
# 6     AP001  2017-11-30  69.80  114.86  4.69  20.17  14.54  10.95  0.12
# 7     AP001  2017-12-01  73.96  113.56  4.58  19.29  13.97  10.95  0.10
# 8     AP001  2017-12-02  89.90  140.20  7.71  26.19  19.87  13.12  0.10
# 9     AP001  2017-12-03  87.14  130.52  0.97  21.31  12.12  14.36  0.15
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0  10.76  109.26     0.17     5.92    0.10    NaN        NaN
# ...

# %%
len(station_day)
# Out:
# 108035

# %%
station_day.shape
# Out:
# (108035, 16)

# %%
station_day.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  86410.000000  65329.000000  90929.000000  91488.000000  92535.000000
# mean      80.272571    157.968427     23.123424     35.240760     41.195055
# std       76.526403    123.418672     34.491019     29.510827     45.145976
# min        0.020000      0.010000      0.010000      0.010000      0.000000
# 25%       31.880000     70.150000      4.840000     15.090000     13.970000
# 50%       55.950000    122.090000     10.290000     27.210000     26.660000
# 75%       99.920000    208.670000     24.980000     46.930000     50.500000
# max     1000.000000   1000.000000    470.000000    448.050000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  59930.000000  95037.000000  82831.000000  82467.000000  76580.000000
# mean      28.732875      1.605749     12.257634     38.134836      3.358029
# ...

# %%
station_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108035 entries, 0 to 108034
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   StationId   108035 non-null  object
#  1   Date        108035 non-null  object
#  2   PM2.5       86410 non-null   float64
#  3   PM10        65329 non-null   float64
#  4   NO          90929 non-null   float64
#  5   NO2         91488 non-null   float64
#  6   NOx         92535 non-null   float64
#  7   NH3         59930 non-null   float64
#  8   CO          95037 non-null   float64
#  9   SO2         82831 non-null   float64
#  10  O3          82467 non-null   float64
#  11  Benzene     76580 non-null   float64
#  12  Toluene     69333 non-null   float64
#  13  Xylene      22898 non-null   float64
#  14  AQI         87025 non-null   float64
#  15  AQI_Bucket  87025 non-null   object
# dtypes: float64(13), object(3)
# memory usage: 13.2+ MB

# %% [markdown]
# ```````    Will have to convert Date of object type to Data of Date Type.  ````````

# %%
station_day['Date']=station_day['Date'].astype('datetime64[ns]')

# %%
station_day.dtypes
# Out:
# StationId             object
# Date          datetime64[ns]
# PM2.5                float64
# PM10                 float64
# NO                   float64
# NO2                  float64
# NOx                  float64
# NH3                  float64
# CO                   float64
# SO2                  float64
# O3                   float64
# Benzene              float64
# Toluene              float64
# Xylene               float64
# AQI                  float64
# AQI_Bucket            object
# dtype: object

# %%
stations = pd.read_csv(r'Datasets/air_quality/stations.csv')

# %%
stations.head()
# Out:
#   StationId                                     StationName  \
# 0     AP001                  Secretariat, Amaravati - APPCB
# 1     AP002  Anand Kala Kshetram, Rajamahendravaram - APPCB
# 2     AP003                      Tirumala, Tirupati - APPCB
# 3     AP004                 PWD Grounds, Vijayawada - APPCB
# 4     AP005          GVM Corporation, Visakhapatnam - APPCB
#
#                 City           State  Status
# 0          Amaravati  Andhra Pradesh  Active
# 1  Rajamahendravaram  Andhra Pradesh     NaN
# 2           Tirupati  Andhra Pradesh     NaN
# 3         Vijayawada  Andhra Pradesh     NaN
# 4      Visakhapatnam  Andhra Pradesh  Active

# %%
stations[stations['StationId'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [StationId, StationName, City, State, Status]
# Index: []

# %%
station_day
# Out:
#        StationId       Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001 2017-11-24  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001 2017-11-25  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001 2017-11-26  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001 2017-11-27  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001 2017-11-28  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...        ...    ...     ...    ...     ...     ...    ...
# 108030     WB013 2020-06-27   8.65   16.46    NaN     NaN     NaN    NaN
# 108031     WB013 2020-06-28  11.80   18.47    NaN     NaN     NaN    NaN
# 108032     WB013 2020-06-29  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013 2020-06-30  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013 2020-07-01  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %%
new_station=station_day.merge(stations,on='StationId')

# %%
new_station
# Out:
#        StationId       Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001 2017-11-24  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001 2017-11-25  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001 2017-11-26  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001 2017-11-27  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001 2017-11-28  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...        ...    ...     ...    ...     ...     ...    ...
# 108030     WB013 2020-06-27   8.65   16.46    NaN     NaN     NaN    NaN
# 108031     WB013 2020-06-28  11.80   18.47    NaN     NaN     NaN    NaN
# 108032     WB013 2020-06-29  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013 2020-06-30  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013 2020-07-01  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket  \
# ...

# %% [markdown]
# New Station contains the merged file station_day and stations on StationId.

# %% [markdown]
# Files were merged inorder to get a few categorical columns such as Staion Names and Status.
