# %%
import pandas as pd

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'a v ha.zip',
#  'air_quality.zip',
#  'Body performace.zip',
#  'climate_india.zip',
#  'crypto.zip',
#  'customer_segmentation.zip',
#  'Domains.txt',
#  'ds',
#  'heart failure.zip',
#  'Leukemia.zip',
#  'National Family Health Survey.zip',
#  'rough.ipynb',
#  'semi conductor sortage.zip',
#  'TESLA STOCKS.zip',
#  'Vechile Insurace fraud.zip',
#  'Youtube dislikes.zip']

# %%
os.path.abspath('')
# Out:
# 'C:\\Users\\PIYUSH SINHA\\Downloads\\DATASETS'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\PIYUSH SINHA\\Downloads\\DATASETS'

# %%
# pd.read_csv(r'C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\PIYUSH SINHA\\Downloads\\DATASETS\\ds\\NFHS\\districtwise_data\\pdfs\\telangana-Copy'

# %%
import os
import sys
folder = r'C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy'
for filename in os.listdir(folder):
    infilename = os.path.join(folder,filename)
    print(infilename)
# Out:
# C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy\komaram_bheem_asifabad.pdf
# C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy\mahabubabad.pdf
# C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy\mahabubnagar.pdf
# C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy\mancherial.pdf
# C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy\medak.pdf
# C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy\medchal_malkajgiri.pdf
# C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy\nagarkurnool.pdf
# C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy\nalgonda.pdf
# C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy\nirmal.pdf
# ...

# %%
os.chdir(r'C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana-Copy')

# %%
import os
import sys
folder = r'C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\pdfs\telangana'
for filename in os.listdir(folder):
    infilename = os.path.join(folder,filename)
    if not os.path.isfile(infilename): continue
    file,ext = os.path.splitext(filename)
    newpath=file+'.pdf'
    os.rename(infilename,newpath)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\PIYUSH SINHA\\Downloads\\DATASETS\\ds\\NFHS\\districtwise_data\\pdfs\\telangana-Copy'

# %%
os.chdir(r'C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\NFHS\districtwise_data\json\odisha')

# %%
pd.read_json('jajapur.json')
# Out:
#                                                  intro  n_households  n_women  \
# 1    Introduction The National Family Health Survey...           889      959
# 10   Introduction The National Family Health Survey...           889      959
# 100  Introduction The National Family Health Survey...           889      959
# 101  Introduction The National Family Health Survey...           889      959
# 102  Introduction The National Family Health Survey...           889      959
# ..                                                 ...           ...      ...
# 95   Introduction The National Family Health Survey...           889      959
# 96   Introduction The National Family Health Survey...           889      959
# 97   Introduction The National Family Health Survey...           889      959
# 98   Introduction The National Family Health Survey...           889      959
# 99   Introduction The National Family Health Survey...           889      959
#
# ...

# %%
weather=pd.read_csv(r'C:\Users\PIYUSH SINHA\Downloads\DATASETS\ds\weather_data.csv')

# %%
weather
# Out:
#               id  city_name  city_id  latitude  longitude  \
# 0         103348  Amarawati  1263594     16.00    76.9600
# 1         103349  Amarawati  1263594     16.00    76.9600
# 2         103350  Amarawati  1263594     16.00    76.9600
# 3         103351  Amarawati  1263594     16.00    76.9600
# 4         103352  Amarawati  1263594     16.00    76.9600
# ...          ...        ...      ...       ...        ...
# 5634117  5738569     Badaun  1275163     28.05    79.1167
# 5634118  5738570     Badaun  1275163     28.05    79.1167
# 5634119  5738571     Badaun  1275163     28.05    79.1167
# 5634120  5738572     Badaun  1275163     28.05    79.1167
# 5634121  5738573     Badaun  1275163     28.05    79.1167
#
#                             dt_txt   temp  temp_min  temp_max  pressure  \
# 0        2020-01-29 08:30:00+05:30  23.45     23.45     23.45      1016
# 1        2020-01-29 11:30:00+05:30  27.91     27.91     27.91      1015
# ...

# %%
# Out:
#        id  city_name  city_id  latitude  longitude
# 0  103348  Amarawati  1263594      16.0      76.96
# 1  103349  Amarawati  1263594      16.0      76.96
# 2  103350  Amarawati  1263594      16.0      76.96
# 3  103351  Amarawati  1263594      16.0      76.96
# 4  103352  Amarawati  1263594      16.0      76.96
# 5  103353  Amarawati  1263594      16.0      76.96

# %%
avg=weather.groupby(by='city_name').agg('mean')

# %%
avg
# Out:
#                          id    city_id   latitude   longitude       temp  \
# city_name
# Adilabad       2.905195e+06  1279344.0  19.669664   78.530336  27.989001
# Agra           2.917349e+06  1279259.0  27.180337   78.019663  27.781478
# Ahmedabad      2.918149e+06  1279233.0  23.030337   72.619663  28.862375
# Ahmednagar     2.916989e+06  1279228.0  19.080337   74.730337  25.967260
# Aizawl         2.928048e+06  1279186.0  23.730339   92.719661  19.812412
# ...                     ...        ...        ...         ...        ...
# West District  2.918189e+06  1668399.0  24.140143  120.670102  24.362882
# Wokha          2.921768e+06  1252840.0  26.100000   94.269661  14.827727
# Yavatmal       2.916549e+06  1252770.0  20.400000   78.130337  27.196503
# Zunheboto      2.926033e+06  1252653.0  25.969660   94.519660  16.681506
# kapurthala     2.926008e+06  1267911.0  31.379938   75.380482  25.338114
#
#                 temp_min   temp_max     pressure    sea_level   grnd_level  \
# ...

# %%
weather
# Out:
#               id  city_name  city_id  latitude  longitude  \
# 0         103348  Amarawati  1263594     16.00    76.9600
# 1         103349  Amarawati  1263594     16.00    76.9600
# 2         103350  Amarawati  1263594     16.00    76.9600
# 3         103351  Amarawati  1263594     16.00    76.9600
# 4         103352  Amarawati  1263594     16.00    76.9600
# ...          ...        ...      ...       ...        ...
# 5634117  5738569     Badaun  1275163     28.05    79.1167
# 5634118  5738570     Badaun  1275163     28.05    79.1167
# 5634119  5738571     Badaun  1275163     28.05    79.1167
# 5634120  5738572     Badaun  1275163     28.05    79.1167
# 5634121  5738573     Badaun  1275163     28.05    79.1167
#
#                             dt_txt   temp  temp_min  temp_max  pressure  \
# 0        2020-01-29 08:30:00+05:30  23.45     23.45     23.45      1016
# 1        2020-01-29 11:30:00+05:30  27.91     27.91     27.91      1015
# ...

# %%
weather.drop_duplicates()
# Out:
#               id  city_name  city_id  latitude  longitude  \
# 0         103348  Amarawati  1263594     16.00    76.9600
# 1         103349  Amarawati  1263594     16.00    76.9600
# 2         103350  Amarawati  1263594     16.00    76.9600
# 3         103351  Amarawati  1263594     16.00    76.9600
# 4         103352  Amarawati  1263594     16.00    76.9600
# ...          ...        ...      ...       ...        ...
# 5634117  5738569     Badaun  1275163     28.05    79.1167
# 5634118  5738570     Badaun  1275163     28.05    79.1167
# 5634119  5738571     Badaun  1275163     28.05    79.1167
# 5634120  5738572     Badaun  1275163     28.05    79.1167
# 5634121  5738573     Badaun  1275163     28.05    79.1167
#
#                             dt_txt   temp  temp_min  temp_max  pressure  \
# 0        2020-01-29 08:30:00+05:30  23.45     23.45     23.45      1016
# 1        2020-01-29 11:30:00+05:30  27.91     27.91     27.91      1015
# ...
